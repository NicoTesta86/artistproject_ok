# %% [markdown]
# ## Calvin Harris

# %% [markdown]
# Let's watch to his artistc health

# %%
import pandas as pd

artist_connections_path = 'Calvin Harris-Analytics-Artist Connections.csv'
artist_connections_df = pd.read_csv(artist_connections_path)


artist_connections_df
# Out:
#              Artist  Artist country Artist genre  Viberate rank  Genre rank  \
# 0     Ariana Grande   United States          Pop              6           4
# 1           Rihanna        Barbados          Pop             10           6
# 2        Katy Perry   United States          Pop             20          15
# 3          Dua Lipa  United Kingdom          Pop             23          18
# 4      Jason Derulo   United States          Pop             25          19
# ..              ...             ...          ...            ...         ...
# 995      Ann Wilson   United States         Rock          16091        1537
# 996        Jai Wolf   United States   Electronic          16101        1303
# 997           ESSEL  United Kingdom   Electronic          16161        1312
# 998  Terrace Martin   United States          R&B          16162         691
# 999  Frankie Grande   United States         Rock          16178        1545
#
#          Instagram              X     Soundcloud
# ...

# %% [markdown]
# The data from the "Calvin Harris-Analytics-Artist Connections.csv" file reveal Calvin Harris's connections with other artists based on various parameters, including the artist's country of origin, genre, Viberate ranking, genre ranking, and the type of connection on social platforms like Instagram and Soundcloud. Here's a summary of the top connected artists:
#
# - Ariana Grande: Pop, United States, global rank 6, genre rank 4, follows on Instagram.
# - Rihanna: Pop, Barbados, global rank 10, genre rank 6, mutual connection on Instagram, and mutually followed on another unspecified platform.
# - Katy Perry: Pop, United States, global rank 20, genre rank 15, mutually followed on an unspecified platform.
# - Dua Lipa: Pop, United Kingdom, global rank 23, genre rank 18, mutual connection on Instagram and another unspecified platform.
# - Jason Derulo: Pop, United States, global rank 25, genre rank 19, follows on Instagram and mutually on another unspecified platform.

# %%
audience_map_path = 'Calvin Harris-Analytics-Audience-Map.csv'
audience_map_df = pd.read_csv(audience_map_path)


audience_map_df.head()
# Out:
#           Country Viberate overall audience (%)  Spotify monthly listeners  \
# 0   United States                        17.24%                  2984942.0
# 1          Brazil                        10.22%                  1193567.0
# 2  United Kingdom                         8.50%                  2222672.0
# 3          Mexico                         7.34%                  1194407.0
# 4       Australia                         4.64%                  2565604.0
#
#   Spotify monthly listeners (%)  Spotify monthly listeners growth  \
# 0                        13.80%                               NaN
# 1                         5.52%                               NaN
# 2                        10.27%                               NaN
# 3                         5.52%                               NaN
# 4                        11.86%                               NaN
#
#    Youtube monthly views Youtube monthly views (%)  \
# 0             13251148.0                    13.23%
# ...

# %% [markdown]
# The "Calvin Harris-Analytics-Audience-Map.csv" file provides a detailed breakdown of Calvin Harris's audience demographics across various countries and platforms. Here's a summary of the top countries with the highest percentage of his overall audience, along with key metrics from platforms like Spotify, YouTube, Instagram, and TikTok:
#
# - United States:
#         Overall audience: 17.24%
#         Spotify monthly listeners: 2,984,942 (13.80% of his total Spotify audience)
#         YouTube monthly views: 13,251,148 (13.23%)
#         Instagram followers: 1,647,227 (19.39%)
#         TikTok followers: 410,637 (45.85%)
#
# - Brazil:
#         Overall audience: 10.22%
#         Spotify monthly listeners: 1,193,567 (5.52%)
#         YouTube monthly views: 8,275,868 (8.26%)
#         Instagram followers: 1,185,671 (13.96%)
#         TikTok followers: 42,198 (4.71%)
#
# - United Kingdom:
#         Overall audience: 8.50%
#         Spotify monthly listeners: 2,222,672 (10.27%)
#         YouTube monthly views: 6,120,294 (6.11%)
#         Instagram followers: 724,115 (8.53%)
#         TikTok followers: 173,935 (19.42%)
#
# - Mexico:
#         Overall audience: 7.34%
#         Spotify monthly listeners: 1,194,407 (5.52%)
#         YouTube monthly views: 7,672,061 (7.66%)
#         Instagram followers: 823,619 (9.70%)
#         TikTok followers: 60,952 (6.81%)
#
# - Australia:
#         Overall audience: 4.64%
#         Spotify monthly listeners: 2,565,604 (11.86%)
#         YouTube monthly views: 2,120,221 (2.12%)
#         Instagram followers: 198,996 (2.34%)
#         TikTok followers: 19,359 (2.16%)
#
# These metrics indicate a strong global presence, with significant audiences in the United States, Brazil, the United Kingdom, Mexico, and Australia. The platform distribution shows a diverse engagement across Spotify, YouTube, Instagram, and TikTok, suggesting a well-rounded digital footprint.

# %%
career_performance_path = 'Calvin Harris-Analytics-Career Performance.csv'
career_performance_df = pd.read_csv(career_performance_path)

career_performance_df.head()
# Out:
#          Date  Viberate performance points  Viberate rank
# 0  2023-02-27                     14943800            NaN
# 1  2023-02-28                     14976900           53.0
# 2  2023-03-01                     15023100           53.0
# 3  2023-03-02                     15120300           53.0
# 4  2023-03-03                     15112300           53.0

# %% [markdown]
# The "Calvin Harris-Analytics-Career Performance.csv" file tracks the performance of Calvin Harris over time, showing the evolution of his "Viberate performance points" and his rank according to Viberate. Here's a brief overview of the data provided:
#
# - Date: The data begins from February 27, 2023, and continues onwards, providing a timeline of his performance metrics.
#     Viberate Performance Points: These points seem to represent a cumulative or overall measure of his performance in the industry, starting at 14,943,800 points and showing changes over the days.
# - Viberate Rank: His rank according to Viberate, which appears on February 28, 2023, at 53rd position, and remains constant in the snapshot provided.
#
# This dataset can be used to analyze trends in Calvin Harris's career performance over time, potentially identifying peaks or declines in his popularity or succes

# %%
import matplotlib.pyplot as plt

career_performance_df['Date'] = pd.to_datetime(career_performance_df['Date'])

plt.figure(figsize=(12, 6))
plt.plot(career_performance_df['Date'], career_performance_df['Viberate performance points'], marker='o', linestyle='-', color='blue')
plt.title('Calvin Harris Career Performance Over Time')
plt.xlabel('Date')
plt.ylabel('Viberate Performance Points')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout() 

plt.show()

# %% [markdown]
# The plot above illustrates the trend in Calvin Harris's career performance over time, as measured by Viberate performance points. From the provided data snippet, we observe a general upward trend in his performance points, indicating a positive trajectory in his career metrics during this period.
#
# This visualization helps to quickly grasp the overall performance and could be enriched with a more detailed dataset spanning longer periods or incorporating additional metrics for a comprehensive analysis.

# %%
# Carico il file "Calvin Harris-Analytics-Engagement.csv" per analizzarlo
engagement_path = 'Calvin Harris-Analytics-Engagement.csv'
engagement_df = pd.read_csv(engagement_path)

# Visualizzo le prime righe del dataframe per avere un'idea dei dati
engagement_df.head()
# Out:
#          Date  Spotify streams  Youtube views  Instagram post likes  Shazams  \
# 0  2023-03-06         66482075       42534275                 61000   160514
# 1  2023-03-13         65069777       44764723                 37500   324941
# 2  2023-03-20         74486943       57358036                 15500   297501
# 3  2023-03-27         75325560       48315614                189000   389153
# 4  2023-04-03         84835618       45104319                117000   438203
#
#    Airplay spins  X likes  Soundcloud plays  Tiktok likes
# 0          23000      143            116046       1035596
# 1          31985     8841            312675        623933
# 2          31969     1409            881039        427390
# 3          31314     5495            976808        405185
# 4          30668    12416           1284502        242104

# %% [markdown]
# The "Calvin Harris-Analytics-Engagement.csv" file provides insights into Calvin Harris's engagement metrics across different platforms for several weeks. Here's an overview of the types of engagement data included:
#
# - Date: Weekly snapshots of engagement data starting from March 6, 2023.
# - Spotify Streams: The number of streams on Spotify.
# - YouTube Views: The number of views on YouTube.
# - Instagram Post Likes: The number of likes on Instagram posts.
# - Shazams: The number of times tracks have been identified on Shazam.
# - Airplay Spins: The number of times tracks have been played on the air.
# - X Likes: The likes on an unspecified platform (possibly could be a social media platform).
# - Soundcloud Plays: The number of plays on Soundcloud.
# - TikTok Likes: The number of likes on TikTok.
#
# This data provides a comprehensive view of engagement across a range of digital platforms, reflecting the audience's interactions with Calvin Harris's content. For a clearer understanding, we can visualize these engagement metrics over time to identify trends, spikes, or declines in audience engagement

# %%
fanbase_daily_growth_path = 'Calvin Harris-Analytics-Fanbase Daily Growth and Engagement.csv'
fanbase_daily_growth_df = pd.read_csv(fanbase_daily_growth_path)

fanbase_daily_growth_df.head()
# Out:
#          Date  Spotify followers  Spotify followers change  \
# 0  2023-03-27         23270633.0                       0.0
# 1  2023-03-28         23272319.0                    1686.0
# 2  2023-03-29         23274094.0                    1775.0
# 3  2023-03-30         23275917.0                    1823.0
# 4  2023-03-31         23277965.0                    2048.0
#
#    Spotify monthly listeners  Spotify monthly listeners change  \
# 0                   62436911                                 0
# 1                   62521932                             85021
# 2                   62633773                            111841
# 3                   62728979                             95206
# 4                   62818719                             89740
#
#    Youtube subscribers  Youtube subscribers change  TikTok followers  \
# 0           18700000.0                         0.0         1000000.0
# 1           18700000.0                         0.0         1000000.0
# ...

# %% [markdown]
# The "Calvin Harris-Analytics-Fanbase Daily Growth and Engagement.csv" file details the daily changes and engagement across Calvin Harris's major social and streaming platforms. This dataset provides a snapshot starting from March 27, 2023, and includes the following metrics:
#
# - Spotify Followers: Total followers and daily change.
# - Spotify Monthly Listeners: Total monthly listeners and daily change.
# - YouTube Subscribers: Total subscribers and daily change.
# - TikTok Followers: Total followers, daily change, likes, and views.
# - Instagram Followers: Total followers, daily change, and likes.
# - SoundCloud Followers: Total followers, daily change, and plays.
#
# This comprehensive dataset allows for a detailed analysis of the daily growth and engagement of Calvin Harris's fanbase on key digital platforms. By analyzing these metrics, we can identify trends, such as periods of significant growth or engagement spikes, which might be correlated with album releases, single drops, or other significant events in his career.

# %%
fanbase_daily_growth_df['Date'] = pd.to_datetime(fanbase_daily_growth_df['Date'])

fig, ax1 = plt.subplots(figsize=(14, 7))

color = 'tab:red'
ax1.set_xlabel('Date')
ax1.set_ylabel('Spotify Followers', color=color)
ax1.plot(fanbase_daily_growth_df['Date'], fanbase_daily_growth_df['Spotify followers'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  
color = 'tab:blue'
ax2.set_ylabel('Daily Change in Spotify Followers', color=color)  #
ax2.plot(fanbase_daily_growth_df['Date'], fanbase_daily_growth_df['Spotify followers change'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  
plt.title('Calvin Harris Spotify Followers Growth and Daily Change')
plt.show()

# %% [markdown]
# The plot illustrates Calvin Harris's Spotify followers' growth alongside the daily change in followers. The red line represents the total number of Spotify followers over time, showing a general upward trend. The blue line indicates the daily change in followers, providing insight into how his fanbase grows day by day.
#
# This visualization helps to understand the dynamics of his Spotify presence, showing not just the overall growth but also the variability in how his fanbase expands on a daily basis. It's interesting to note periods where there might be spikes in daily growth, which could correlate with new music releases, promotional activities, or other events.

# %%
fanbase_evolution_path = 'Calvin Harris-Analytics-Fanbase Evolution Through Time.csv'
fanbase_evolution_df = pd.read_csv(fanbase_evolution_path)

fanbase_evolution_df.head()
# Out:
#          Date  Spotify followers total  Spotify followers new  \
# 0  2023-03-06                 23226441                   8292
# 1  2023-03-13                 23242045                  15771
# 2  2023-03-20                 23255723                  13956
# 3  2023-03-27                 23268570                  12818
# 4  2023-04-03                 23282135                  13660
#
#    Youtube subscribers total  Youtube subscribers new  \
# 0                   18700000                        0
# 1                   18700000                        0
# 2                   18700000                        0
# 3                   18700000                        0
# 4                   18700000                    50000
#
#    Instagram followers total  Instagram followers new  \
# 0                   10733266                    12409
# 1                   10749541                    14156
# 2                   10760926                    13504
# ...

# %% [markdown]
# GPT
#
# The "Calvin Harris-Analytics-Fanbase Evolution Through Time.csv" file provides an in-depth look at the evolution of Calvin Harris's fanbase across various platforms over time. Here's a quick overview of the data:
#
# - Date: Weekly snapshots starting from March 6, 2023.
# - Spotify Followers: Total and new followers each week.
# - YouTube Subscribers: Total and new subscribers each week.
# - Instagram Followers: Total and new followers each week.
# - Facebook Followers: Total and new followers each week.
# - Deezer Fans: Total and new fans each week.
# - X Followers: Total and new followers each week (the platform "X" is not specified but could represent another social media or music platform).
# - SoundCloud Followers: Total and new followers each week.
# - TikTok Followers: Total and new followers each week.
#
# This dataset offers a comprehensive view of how Calvin Harris's fanbase has changed across multiple platforms, highlighting both the overall size and the weekly growth of his audience. Analyzing these trends can provide insights into his popularity dynamics, the effectiveness of new releases or promotional activities, and the broader appeal across different social media and streaming platforms.

# %%
platforms = ['Spotify followers total', 'Youtube subscribers total', 'Instagram followers total', 'Tiktok followers total']

fanbase_evolution_df['Date'] = pd.to_datetime(fanbase_evolution_df['Date'])

plt.figure(figsize=(14, 8))

for platform in platforms:
    plt.plot(fanbase_evolution_df['Date'], fanbase_evolution_df[platform], label=platform)

plt.title('Calvin Harris Fanbase Growth Across Platforms Over Time')
plt.xlabel('Date')
plt.ylabel('Total Followers/Subscribers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# The graph illustrates the growth of Calvin Harris's fanbase across four key platforms: Spotify, YouTube, Instagram, and TikTok, over the provided time period. Each line represents the total number of followers or subscribers on the respective platform, showing how Calvin Harris's audience has evolved.
#
# This visualization provides a clear view of the dynamics and growth patterns on each platform, highlighting which platforms have seen the most significant increases in followers or subscribers. Such insights can help in understanding where his audience is most engaged and how his digital presence is expanding over time.

# %%
fanbase_growth_path = 'Calvin Harris-Analytics-Fanbase Growth.csv'
fanbase_growth_df = pd.read_csv(fanbase_growth_path)

fanbase_growth_df.head()
# Out:
#          Date  Spotify followers  Youtube subscribers  Instagram followers  \
# 0  2023-03-06               8292                    0                12409
# 1  2023-03-13              15771                    0                14156
# 2  2023-03-20              13956                    0                13504
# 3  2023-03-27              12818                    0                17216
# 4  2023-04-03              13660                50000                17269
#
#    Facebook followers  Deezer fans  X followers  Soundcloud followers  \
# 0               -1697         1542        -3467                   255
# 1               -6197         2721        -4745                   530
# 2               -3385         3105        -5831                   853
# 3               -4191         2978       -10048                   798
# 4               -2409         2986       -11054                   744
#
#    Tiktok followers
# 0             69100
# 1             31633
# 2             24567
# ...

# %% [markdown]
# The "Calvin Harris-Analytics-Fanbase Growth.csv" file provides weekly updates on the growth of Calvin Harris's fanbase across various platforms. This dataset spans from March 6, 2023, offering insights into the number of new followers or fans he gained on each platform every week. Here's a breakdown of the platforms included:
#
# - Spotify Followers: Shows the weekly increase in Spotify followers.
# - YouTube Subscribers: Indicates the weekly change in YouTube subscribers.
# - Instagram Followers: Reflects the weekly growth in Instagram followers.
# - Facebook Followers: Details the weekly change in Facebook followers, with negative numbers indicating a decrease.
# - Deezer Fans: Shows the weekly increase in Deezer fans.
# - X Followers: Represents the weekly change in followers on an unspecified platform (X), with negative numbers suggesting a decrease.
# - SoundCloud Followers: Indicates the weekly growth in SoundCloud followers.
# - TikTok Followers: Shows the weekly increase in TikTok followers.
#
# This data offers a comprehensive view of how Calvin Harris's fanbase is evolving across major digital platforms, highlighting areas of significant growth as well as platforms where the fanbase might be shrinking. It's particularly interesting to note the dynamics of social media platforms compared to streaming services, offering insights into where his audience is most active and engaged.

# %%
fanbase_growth_df['Date'] = pd.to_datetime(fanbase_growth_df['Date'])

plt.figure(figsize=(14, 8))

platforms_growth = ['Spotify followers', 'Youtube subscribers', 'Instagram followers', 'Tiktok followers']

for platform in platforms_growth:
    plt.plot(fanbase_growth_df['Date'], fanbase_growth_df[platform], label=platform, marker='o')

plt.title('Weekly Fanbase Growth on Key Platforms for Calvin Harris')
plt.xlabel('Date')
plt.ylabel('Number of New Followers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# The graph illustrates the weekly growth of Calvin Harris's fanbase on key platforms: Spotify, YouTube, Instagram, and TikTok, over the provided time period. Each line represents the number of new followers or subscribers gained each week on the respective platform.
#
# This visualization highlights several key points:
#
# - The TikTok platform shows significant spikes, indicating periods of substantial growth, which might be linked to specific content going viral or promotional campaigns.
# - Spotify and Instagram show more consistent growth patterns, with Spotify experiencing a steady increase in followers, reflecting a solid and growing interest in Calvin Harris's music.
# - YouTube shows a major spike, possibly indicating the release of new video content that attracted a large number of subscribers in a short period.
#
# Analyzing these trends provides valuable insights into where Calvin Harris's engagement strategies are most effective and where his audience is most actively growing. This can inform future marketing and promotional efforts to leverage the platforms with the highest engagement and growth potential.

# %%
fanbase_total_distribution_path = 'Calvin Harris-Analytics-Fanbase Total Distribution.csv'
fanbase_total_distribution_df = pd.read_csv(fanbase_total_distribution_path)

fanbase_total_distribution_df.head()
# Out:
#                      Channel     Total  Percentage
# 0          Spotify followers  22414310       22.45
# 1        YouTube subscribers  19200000       19.23
# 2         Facebook followers  14705245       14.73
# 3                Deezer fans  11832065       11.85
# 4  [object Object] followers  11749118       11.77

# %% [markdown]
# The "Calvin Harris-Analytics-Fanbase Total Distribution.csv" file offers a snapshot of the total distribution of Calvin Harris's fanbase across various channels, providing insights into where his audience is most concentrated. Here's a brief overview of the data provided:
#
# - Spotify followers: 22,414,310 followers, making up 22.45% of his total fanbase.
# - YouTube subscribers: 19,200,000 subscribers, accounting for 19.23% of his total fanbase.
# - Facebook followers: 14,705,245 followers, representing 14.73% of his total fanbase.
# - Deezer fans: 11,832,065 fans, which is 11.85% of his total fanbase.
# - ???[object Object] followers: 11,749,118 followers, making up 11.77% of his total fanbase. This seems to be a formatting error in the dataset and may refer to another platform or metric.
#
# This distribution highlights the broad and diverse digital footprint of Calvin Harris, with a significant presence on major streaming platforms and social media. The data illustrates the importance of multi-platform engagement to maintain and grow an artist's fanbase.

# %%
fanbase_total_distribution_df['Channel'] = fanbase_total_distribution_df['Channel'].replace('[object Object] followers', 'Unknown Platform Followers')

channels = fanbase_total_distribution_df['Channel']
totals = fanbase_total_distribution_df['Total']

plt.figure(figsize=(10, 8))
plt.pie(totals, labels=channels, autopct='%1.1f%%', startangle=140)
plt.title('Calvin Harris Fanbase Total Distribution Across Channels')
plt.axis('equal')  

plt.show()

# %% [markdown]
# The pie chart visualizes the total distribution of Calvin Harris's fanbase across various channels. It clearly illustrates the proportions of his audience on platforms like Spotify, YouTube, Facebook, Deezer, and an unidentified platform (labeled as "Unknown Platform Followers" due to a formatting issue in the dataset).
#
# This visualization helps to understand not just the size but the diversity of Calvin Harris's global fanbase, highlighting the importance of a multi-platform presence for reaching and engaging with audiences effectively.

# %%
top_tracks_path = 'Calvin Harris-Analytics-Top Tracks on Music Channels.csv'
top_tracks_df = pd.read_csv(top_tracks_path)

top_tracks_df.head()
# Out:
#    Channel                                              Track  \
# 0  Airplay  Calvin Harris feat. Ellie Goulding - Outside (...
# 1  Airplay  Calvin Harris & Disciples - How Deep Is Your Love
# 2   Shazam        We Found Love - Rihanna Feat. Calvin Harris
# 3   Shazam                      Feel So Close - Calvin Harris
# 4   Shazam                             Summer - Calvin Harris
#
#                   Artists Release date  Engagement 1w  Engagement 1m  \
# 0           Calvin Harris   2021-08-25         1308.0        12600.0
# 1           Calvin Harris   2021-08-25         1875.0        18104.0
# 2  Rihanna, Calvin Harris   2011-01-01        31091.0       129027.0
# 3           Calvin Harris   2011-01-01        12313.0        47383.0
# 4           Calvin Harris   2014-03-14        10716.0        42607.0
#
#    Engagement Total
# 0               NaN
# 1               NaN
# 2        12334131.0
# 3               NaN
# 4        11154595.0

# %% [markdown]
# The "Calvin Harris-Analytics-Top Tracks on Music Channels.csv" file lists Calvin Harris's top tracks on various music channels, offering a glance at their performance in terms of engagement. Here's a brief overview based on the provided data:
#
# - Channel: The music channel where the track is featured, such as Airplay and Shazam.
# - Track: The name of the track, including collaborations.
# - Artists: The artist(s) involved in the track.
# - Release Date: The release date of the track.
# -  Engagement 1w: Engagement within one week.
# - Engagement 1m: Engagement within one month.
#     Engagement Total: The total engagement received.
#
# Highlighted tracks include collaborations with Ellie Goulding and Disciples, as well as Calvin Harris's solo tracks. For example:
#
#     "Outside" featuring Ellie Goulding has shown a recent engagement of 1,308 in one week and 12,600 in one month.
#     "How Deep Is Your Love" with Disciples engaged 1,875 in the past week and 18,104 in the past month.
#     "We Found Love" featuring Rihanna, a major hit, has a total engagement of 12,334,131, showing its long-term popularity.
#
# This data can provide insights into the popularity of Calvin Harris's tracks over time, highlighting the tracks that continue to resonate with audiences worldwide.
