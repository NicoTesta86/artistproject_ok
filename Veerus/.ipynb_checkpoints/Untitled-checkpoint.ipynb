# %% [markdown]
# ### Artist Name: Veerus

# %%
import pandas as pd


career_performance_path = 'Veerus-Analytics-Career Performance(1).csv'
career_performance_df = pd.read_csv(career_performance_path)

career_performance_df
# Out:
#            Date  Viberate performance points  Viberate rank
# 0    2023-02-27                        15887            NaN
# 1    2023-02-28                        15870        54824.0
# 2    2023-03-01                        15763        55113.0
# 3    2023-03-02                        15708        55506.0
# 4    2023-03-03                        15610        55696.0
# ..          ...                          ...            ...
# 361  2024-02-23                        22691        51721.0
# 362  2024-02-24                        22625        51781.0
# 363  2024-02-25                        22623        51886.0
# 364  2024-02-26                        22625        52032.0
# 365  2024-02-27                        22597            NaN
#
# [366 rows x 3 columns]

# %%
import matplotlib.pyplot as plt


career_performance_df['Date'] = pd.to_datetime(career_performance_df['Date'])

plt.figure(figsize=(14, 7))
plt.plot(career_performance_df['Date'], career_performance_df['Viberate performance points'], marker='o', linestyle='-', color='blue')
plt.title('Trend pt Performance in time')
plt.xlabel('date')
plt.ylabel('Pt Performance')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
career_performance_filtered = career_performance_df.dropna(subset=['Viberate rank'])

plt.figure(figsize=(14, 7))
plt.plot(career_performance_filtered['Date'], career_performance_filtered['Viberate rank'], marker='o', linestyle='-', color='red')
plt.title('Veerus Ranking Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Viberate Rank')
plt.gca().invert_yaxis()  # Inverting y-axis as a lower rank number is better
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# The graph depicts the trend of Veerus's ranking over time. Note that the y-axis is inverted, meaning a lower rank (closer to 1) is considered better. The plot shows how the ranking has changed, possibly reflecting the artist's or entity's relative standing within their industry or genre.
#
# Observing the ranking trend can provide insights into periods of significant improvement or decline in Veerus's industry standing. These changes could be linked to specific career events, releases, or external factors affecting the broader industry landscape.

# %%
fig, ax1 = plt.subplots(figsize=(14, 7))

color = 'tab:red'
ax1.set_xlabel('Date')
ax1.set_ylabel('Viberate Performance Points', color=color)
ax1.plot(career_performance_filtered['Date'], career_performance_filtered['Viberate performance points'], color=color, label='Performance Points')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('Viberate Rank', color=color)  # we already handled the x-label with ax1
ax2.plot(career_performance_filtered['Date'], career_performance_filtered['Viberate rank'], color=color, label='Rank')
ax2.tick_params(axis='y', labelcolor=color)
ax2.invert_yaxis()  # Inverting y-axis to keep the rank's orientation consistent

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Performance Points and Viberate Rank Over Time')
plt.show()

# %% [markdown]
# This different visualization combines the trends of both performance points and Viberate rank over time, using a dual-axis line chart. The red line represents the Viberate performance points, and the blue line represents the Viberate rank. The y-axis on the left corresponds to the performance points, and the y-axis on the right, which is inverted, corresponds to the rank.
#
# By comparing these two metrics on the same timeline, we can more easily see how changes in performance points are reflected in the Viberate rank. This visualization emphasizes the relationship between performance improvements and ranking adjustments, providing a clear view of how they have evolved together over time.

# %% [markdown]
# ## Engagement

# %% [markdown]
# The "Engagement" file provides a detailed look at various metrics related to Veerus's audience engagement across different platforms and media for specific dates. Here are the columns included in the dataset:
#
#     Date: The date of the engagement data record.
#     Spotify streams: The number of streams on Spotify.
#     Youtube views: The number of views on Youtube.
#     Instagram post likes: The number of likes on Instagram posts.
#     Shazams: The number of times Veerus's songs were identified on Shazam.
#     Airplay spins: The number of times Veerus's songs were played on the radio.
#     X likes: This column's context isn't clear without additional information, but it could be another social media engagement metric.
#     Soundcloud plays: The number of plays on Soundcloud.
#     Tiktok likes: The number of likes on Tiktok.

# %%
engagement_path = 'Veerus-Analytics-Engagement.csv'
engagement_df = pd.read_csv(engagement_path)


engagement_df.head()
# Out:
#          Date  Spotify streams  Youtube views  Instagram post likes  Shazams  \
# 0  2023-03-06            19987          20125                     0      619
# 1  2023-03-13            21698           1264                     0      928
# 2  2023-03-20            20731          19848                     0      855
# 3  2023-03-27            20510          10947                     0      817
# 4  2023-04-03            21513          11522                    18      705
#
#    Airplay spins  X likes  Soundcloud plays  Tiktok likes
# 0             29        0               950             1
# 1             43        0              1040            26
# 2             45        0              1012             6
# 3             44        0              1028             2
# 4             42        0              1006             0

# %%
# Convertire la colonna "Date" in datetime per una migliore gestione dei dati temporali
engagement_df['Date'] = pd.to_datetime(engagement_df['Date'])

# Grafico delle tendenze di engagement nel tempo per ogni piattaforma
plt.figure(figsize=(16, 10))

# Spotify streams
plt.plot(engagement_df['Date'], engagement_df['Spotify streams'], label='Spotify Streams', marker='o', linestyle='-')
# Youtube views
plt.plot(engagement_df['Date'], engagement_df['Youtube views'], label='Youtube Views', marker='o', linestyle='-')
# Instagram post likes
plt.plot(engagement_df['Date'], engagement_df['Instagram post likes'], label='Instagram Post Likes', marker='o', linestyle='-')
# Shazams
plt.plot(engagement_df['Date'], engagement_df['Shazams'], label='Shazams', marker='o', linestyle='-')
# Airplay spins
plt.plot(engagement_df['Date'], engagement_df['Airplay spins'], label='Airplay Spins', marker='o', linestyle='-')
# X likes
plt.plot(engagement_df['Date'], engagement_df['X likes'], label='X Likes', marker='o', linestyle='-')
# Soundcloud plays
plt.plot(engagement_df['Date'], engagement_df['Soundcloud plays'], label='Soundcloud Plays', marker='o', linestyle='-')
# Tiktok likes
plt.plot(engagement_df['Date'], engagement_df['Tiktok likes'], label='Tiktok Likes', marker='o', linestyle='-')

plt.title('Engagement Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Engagement Metrics')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# The chart illustrates the engagement trends over time across various platforms for Veerus. Each line represents a different engagement metric, including Spotify streams, Youtube views, Instagram post likes, Shazams, Airplay spins, X likes, Soundcloud plays, and Tiktok likes.
#
# Key observations from the chart might include:
#
#     Variability: Engagement metrics vary significantly across platforms, with some showing more pronounced fluctuations than others.
#     Platform Popularity: Some platforms, like Spotify and Youtube, might show consistently higher engagement, suggesting they are more popular or effective channels for Veerus.
#     Special Events: Spikes or dips in the engagement metrics might correlate with special events, releases, or promotional activities.
#     Emerging Trends: New or growing platforms might show increasing engagement over time, indicating shifting audience behaviors or successful outreach efforts.
#
# This overview provides a broad picture of how Veerus's audience interacts with their content across different media. Further analysis could delve into the causes behind trends, the impact of specific campaigns, or comparisons between engagement types to derive actionable insights.

# %%
engagement_averages_no_date = engagement_df.drop('Date', axis=1).mean()


plt.figure(figsize=(12, 8))
engagement_averages_no_date.plot(kind='bar', color='skyblue')
plt.title('Average Engagement per Platform')
plt.xlabel('Platform')
plt.ylabel('Average Engagement')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# This visualization allows us to compare the levels of interaction across various media, highlighting where Veerus enjoys the most popularity or active audience engagement.
#
# Observations from the chart can inform strategic decisions on where to allocate resources for content distribution, marketing efforts, or audience growth strategies.

# %% [markdown]
# To analyze the impact of specific events on engagement metrics, we would ideally need to know the dates of these events or releases (like album releases, significant concerts, or social media campaigns). This information would allow us to pinpoint changes in the engagement data corresponding to these events.
#
# Without specific event dates, we can still look at the engagement data to identify any noticeable spikes or unusual patterns that might suggest the occurrence of an event. Then, we could infer the potential impact of such events based on changes in engagement levels across different platforms.
#
# Let's proceed by identifying any noticeable spikes in the engagement data we have. We'll look for significant changes in Spotify streams, Youtube views, and other metrics that could indicate the influence of specific events.

# %%
# Re-defining the metrics variable to include all engagement metrics excluding 'Date'
metrics = engagement_df.columns[1:]  # All columns except 'Date'

# Plotting the normalized engagement metrics again with the correct metrics variable
plt.figure(figsize=(16, 10))

# Looping through each metric to plot
for metric in metrics:
    plt.plot(normalized_df['Date'], normalized_df[metric], label=metric, marker='o', linestyle='-', markersize=4)

plt.title('Normalized Engagement Metrics Over Time')
plt.xlabel('Date')
plt.ylabel('Normalized Engagement')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# This visualization presents the normalized engagement metrics over time for Veerus, combining multiple metrics into a single plot for clearer overview. By normalizing the data, we can compare the trends across different platforms on a similar scale, making it easier to spot spikes and patterns.
#
# This approach helps identify periods of increased engagement across platforms, possibly indicating the impact of specific events, releases, or campaigns. The use of markers helps in pinpointing exact dates where significant changes occur.

# %% [markdown]
# ## Audience Map

# %% [markdown]
# The "Audience Map" file provides detailed data on Veerus's audience distribution across different countries and platforms. Here's a summary of the key columns in the dataset:
#
#     Country: The country of the audience.
#     Viberate overall audience (%): The percentage of the overall audience located in each country.
#     Spotify monthly listeners: The number of monthly listeners on Spotify from each country.
#     Spotify monthly listeners (%): The percentage of Spotify monthly listeners from each country relative to the total.
#     Spotify monthly listeners growth: Growth in the number of Spotify monthly listeners (the dataset doesn't show this data for now).
#     Youtube monthly views: The number of monthly views on Youtube from each country.
#     Youtube monthly views (%): The percentage of Youtube monthly views from each country relative to the total.
#     Youtube monthly views growth: Growth in the number of Youtube monthly views (the dataset doesn't show this data for now).
#     Youtube subscribers: The number of Youtube subscribers from each country.
#     Youtube subscribers (%): The percentage of Youtube subscribers from each country relative to the total.
#     Instagram followers: The number of Instagram followers from each country.
#     Instagram followers (%): The percentage of Instagram followers from each country relative to the total.
#     Tiktok followers: The number of Tiktok followers from each country.
#     Tiktok followers (%): The percentage of Tiktok followers from each country relative to the total.

# %%
audience_map_path = 'Veerus-Analytics-Audience-Map.csv'
audience_map_df = pd.read_csv(audience_map_path)

audience_map_df.head()
# Out:
#        Country Viberate overall audience (%)  Spotify monthly listeners  \
# 0        Italy                        21.86%                     1260.0
# 1       France                        21.26%                      832.0
# 2      Germany                        20.45%                    15914.0
# 3  Netherlands                         6.68%                     5299.0
# 4      Belgium                         3.44%                     1850.0
#
#   Spotify monthly listeners (%)  Spotify monthly listeners growth  \
# 0                         2.91%                               NaN
# 1                         1.92%                               NaN
# 2                        36.78%                               NaN
# 3                        12.25%                               NaN
# 4                         4.28%                               NaN
#
#    Youtube monthly views  Youtube monthly views (%)  \
# 0                    NaN                        NaN
# ...

# %%
audience_map_df['Viberate overall audience (%)'] = audience_map_df['Viberate overall audience (%)'].str.rstrip('%').astype('float') / 100.0


plt.figure(figsize=(20, 20))
audience_map_df.plot(kind='bar', x='Country', y='Viberate overall audience (%)', color='darkcyan')
plt.title('Geographical Distribution of Audience')
plt.xlabel('Country')
plt.ylabel('Percentage of Overall Audience')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# The bar chart illustrates the geographical distribution of Veerus's audience, showing the percentage of the overall audience by country. This visualization helps identify where Veerus's audience is most concentrated geographically.
#
# Countries with higher percentages represent larger portions of Veerus's total audience, indicating key markets or regions where Veerus has a strong presence. This information can be crucial for planning tours, promotional efforts, or content localization strategies to engage with the audience more effectively.

# %%
# Convertendo le percentuali in valori numerici per Spotify, Youtube, Instagram, e Tiktok
platform_columns = ['Spotify monthly listeners (%)', 'Youtube subscribers (%)', 'Instagram followers (%)', 'Tiktok followers (%)']
for col in platform_columns:
    audience_map_df[col] = audience_map_df[col].str.rstrip('%').astype('float') / 100.0

# Preparare i dati per il grafico
platform_preference_by_country = audience_map_df.melt(id_vars='Country', value_vars=platform_columns, var_name='Platform', value_name='Percentage')

# Sostituire i nomi delle colonne con nomi di piattaforma più leggibili
platform_preference_by_country['Platform'] = platform_preference_by_country['Platform'].replace({
    'Spotify monthly listeners (%)': 'Spotify',
    'Youtube subscribers (%)': 'Youtube',
    'Instagram followers (%)': 'Instagram',
    'Tiktok followers (%)': 'Tiktok'
})

# Grafico
plt.figure(figsize=(16, 10))
sns.barplot(x='Country', y='Percentage', hue='Platform', data=platform_preference_by_country)
plt.title('Platform Preference by Country')
plt.xlabel('Country')
plt.ylabel('Percentage of Platform Users')
plt.xticks(rotation=45)
plt.legend(title='Platform')
plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 4
#       2 platform_columns = ['Spotify monthly listeners (%)', 'Youtube subscribers (%)', 'Instagram followers (%)', 'Tiktok followers (%)']
#       3 for col in platform_columns:
# ----> 4     audience_map_df[col] = audience_map_df[col].str.rstrip('%').astype('float') / 100.0
#       6 # Preparare i dati per il grafico
#       7 platform_preference_by_country = audience_map_df.melt(id_vars='Country', value_vars=platform_columns, var_name='Platform', value_name='Percentage')
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
# ...

# %%
import seaborn as sns

# Assuming the conversion to numeric values for the percentage columns is already done
# Proceeding with the visualization
platform_preference_by_country = audience_map_df.melt(id_vars='Country', value_vars=platform_columns, var_name='Platform', value_name='Percentage')

# Adjusting the 'Platform' column for better readability
platform_preference_by_country['Platform'] = platform_preference_by_country['Platform'].replace({
    'Spotify monthly listeners (%)': 'Spotify',
    'Youtube subscribers (%)': 'Youtube',
    'Instagram followers (%)': 'Instagram',
    'Tiktok followers (%)': 'Tiktok'
})

# Creating the bar plot
plt.figure(figsize=(16, 10))
sns.barplot(x='Country', y='Percentage', hue='Platform', data=platform_preference_by_country)
plt.title('Platform Preference by Country')
plt.xlabel('Country')
plt.ylabel('Percentage of Platform Users')
plt.xticks(rotation=45)
plt.legend(title='Platform')
plt.tight_layout()

plt.show()

# %% [markdown]
# The bar plot now visualizes the platform preference by country for Veerus's audience, comparing the relative popularity of Spotify, Youtube, Instagram, and Tiktok within each listed country. This comparison can inform where to concentrate marketing and promotional efforts based on platform strengths in specific markets.
#
# Key observations could include:
#
#     Country-Specific Preferences: Certain countries may show a stronger preference for one platform over others, indicating where Veerus could focus platform-specific content or advertising.
#     Balanced vs. Skewed Distribution: In some countries, audience engagement might be more evenly distributed across platforms, while in others, one platform may dominate.
#     Opportunities for Growth: Identifying countries with low engagement on specific platforms could highlight opportunities to increase Veerus's presence and audience engagement there.

# %%
# Calculating the mean percentage for platform-specific engagement in each country
audience_map_df['Mean Platform Engagement (%)'] = audience_map_df[platform_columns].mean(axis=1)

# Identifying countries with high overall audience percentages but relatively lower mean platform-specific engagement
growth_opportunities = audience_map_df[['Country', 'Viberate overall audience (%)', 'Mean Platform Engagement (%)']].copy()
growth_opportunities['Engagement Opportunity Gap'] = growth_opportunities['Viberate overall audience (%)'] - growth_opportunities['Mean Platform Engagement (%)']

# Sorting the countries based on the opportunity gap to identify the top countries with growth opportunities
growth_opportunities_sorted = growth_opportunities.sort_values(by='Engagement Opportunity Gap', ascending=False)

# Displaying the sorted countries with the most significant growth opportunities
growth_opportunities_sorted.head()
# Out:
#            Country  Viberate overall audience (%)  \
# 2          Germany                         0.2045
# 5            Spain                         0.0243
# 7    United States                         0.0223
# 13  United Kingdom                         0.0121
# 11     Switzerland                         0.0162
#
#     Mean Platform Engagement (%)  Engagement Opportunity Gap
# 2                       0.127733                    0.076767
# 5                       0.022100                    0.002200
# 7                       0.021533                    0.000767
# 13                      0.012200                   -0.000100
# 11                      0.016733                   -0.000533

# %% [markdown]
# To identify growth opportunities, we'll look for countries where Veerus has a significant overall audience percentage but shows lower engagement on specific platforms. This discrepancy can highlight potential areas for targeted growth efforts, suggesting where increasing platform-specific presence could be especially beneficial.
#
# We'll focus on identifying these opportunities by comparing the overall audience percentage to platform-specific engagement percentages for Spotify, Youtube, Instagram, and Tiktok. Let's proceed with this analysis.
#
# The analysis has identified countries where Veerus has a significant overall audience percentage but relatively lower mean platform-specific engagement. These countries represent opportunities for targeted growth efforts, suggesting that increasing Veerus's presence and engagement on specific platforms could be particularly effective in these markets.
#
#     Germany stands out with the largest "Engagement Opportunity Gap," indicating a substantial audience that might not be fully engaged across all platforms. This suggests a prime opportunity for targeted initiatives to increase platform engagement.
#     Spain and the United States also show positive gaps, albeit smaller, pointing to additional opportunities for engagement growth.
#     United Kingdom and Switzerland appear at the bottom of the top list, with very small or negative gaps, indicating that the platform engagement is already quite aligned with the overall audience size or slightly overperforming.
